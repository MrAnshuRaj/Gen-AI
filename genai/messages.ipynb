# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:openai/gpt-oss-20b")

# %%
model.invoke("Please tell me something about AI")
# Out:
# AIMessage(content='Artificial Intelligence (AI) is a fascinating and rapidly evolving field that essentially involves creating systems capable of performing tasks that typically require human intelligence. These tasks can include things like understanding language, recognizing images, making decisions, and even generating creative content.\n\nHere are a few key aspects to understand about AI:\n\n### 1. **How It Works**\nAt its core, modern AI—especially machine learning (ML) and deep learning—relies on algorithms that can learn patterns from large datasets. Instead of being explicitly programmed with rules, these systems "learn" by adjusting internal parameters based on examples. For instance, a computer vision system learns to recognize cats by analyzing millions of labeled images, gradually improving its accuracy.\n\n### 2. **Types of AI**\n- **Narrow AI (Weak AI):** This is the most common form today. It’s designed to perform a specific task, such as playing chess, recommending movies, or translating languages. It doesn’t possess general intelligence and can’t go beyond its programmed scope.\n- **General AI (Strong AI):** This is a theoretical form of AI that would possess the ability to understand, learn, and apply knowledge across a wide range of tasks at a human level or beyond. It does not currently exist.\n- **Super AI:** A hypothetical future scenario where AI surpasses human intelligence in all aspects, including creativity, social skills, and problem-solving.\n\n### 3. **Current Applications**\nAI is already deeply integrated into our daily lives:\n- **Healthcare:** Diagnosing diseases from medical images, drug discovery, and personalized treatment plans.\n- **Transportation:** Autonomous vehicles, traffic optimization, and logistics routing.\n- **Creative Arts:** Generating text, images, music, and code (like the AI you’re interacting with now).\n- **Customer Service:** Chatbots and virtual assistants that handle inquiries 24/7.\n- **Finance:** Fraud detection, algorithmic trading, and risk assessment.\n\n### 4. **Ethical and Social Considerations**\nAs AI becomes more powerful, it raises important questions:\n- **Bias:** If AI is trained on biased data, it can perpetuate or even amplify societal biases (e.g., in hiring or lending).\n- **Privacy:** AI systems often require vast amounts of data, raising concerns about surveillance and personal data security.\n- **Job Displacement:** Automation may change the job market, requiring workforce reskilling and new economic models.\n- **Accountability:** Who is responsible when an AI makes a wrong decision? Developers, users, or the AI itself?\n\n### 5. **The Future**\nThe field is moving toward more sophisticated models that can reason, plan, and collaborate with humans more effectively. There’s also a growing focus on **responsible AI**, which aims to ensure that these technologies are safe, transparent, fair, and beneficial to society.\n\nIn short, AI is not just a technology—it’s a tool that is reshaping industries, science, and even how we think about intelligence itself. It’s a double-edged sword: immensely powerful for good, but requiring careful governance to mitigate risks.\n\nIs there a specific aspect of AI you’d like to dive deeper into?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 665, 'prompt_tokens': 18, 'total_tokens': 683, 'completion_time': 1.343490129, 'completion_tokens_details': None, 'prompt_time': 0.00124935, 'prompt_tokens_details': None, 'queue_time': 0.04861038, 'total_time': 1.344739479}, 'model_name': 'qwen/qwen3.8-27b', 'system_fingerprint': 'fp_4560dae850', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0ae93-baae-71a2-9420-ecc83d8d8316-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 665, 'total_tokens': 683})

# %% [markdown]
# ### Text Prompts

# %% [markdown]
# Text prompts are strings - ideal for straightforward generation tasks where you dont need to retain conversation history

# %%
model.invoke("Do you know about langchain")
# Out:
# AIMessage(content='Yes, I am very familiar with **LangChain**.\n\n**LangChain** is a popular open-source framework for developing applications powered by Large Language Models (LLMs). It provides tools and abstractions that make it easier to build complex AI applications, such as chatbots, RAG (Retrieval-Augmented Generation) systems, agents, and other LLM-powered workflows.\n\n### Key Features of LangChain:\n\n1. **LLM Integration**: Supports a wide variety of LLMs (OpenAI, Anthropic, Hugging Face, local models via Ollama, etc.) through a unified interface.\n2. **Chains**: Allows you to compose multiple LLM calls and other operations into complex workflows (e.g., prompt → LLM → parse output → call another LLM).\n3. **Retrieval-Augmented Generation (RAG)**: Provides tools to connect LLMs with external knowledge sources (databases, documents, APIs) for more accurate and context-aware responses.\n4. **Agents**: Enables LLMs to use tools and make decisions in a loop (e.g., searching the web, calling APIs, executing code) to solve tasks autonomously.\n5. **Memory**: Offers mechanisms to maintain context and state across multiple interactions in a conversation.\n6. **LangSmith**: A companion platform for debugging, evaluating, and monitoring LLM applications.\n\n### Common Use Cases:\n- Building conversational AI assistants\n- Creating document Q&A systems\n- Automating tasks with AI agents\n- Data extraction and summarization\n- Multi-step reasoning workflows\n\n### Two Main Libraries:\n- **`langchain`**: The core library for building chains, agents, and integrations.\n- **`langgraph`**: A newer, more flexible library for building stateful, multi-actor applications and complex control flows (especially useful for agents).\n\nWould you like help with a specific LangChain project, code example, or concept?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 405, 'prompt_tokens': 18, 'total_tokens': 423, 'completion_time': 0.799410356, 'completion_tokens_details': None, 'prompt_time': 0.001177969, 'prompt_tokens_details': None, 'queue_time': 0.05246952, 'total_time': 0.800588325}, 'model_name': 'qwen/qwen3.8-27b', 'system_fingerprint': 'fp_4560dae850', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0ae95-d91a-77c3-a25e-bf90d0380882-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 405, 'total_tokens': 423})

# %% [markdown]
# ### Use text prompts when:
#
# + You have a single, standalone request
# + You don’t need conversation history
# + You want minimal code complexity

# %% [markdown]
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# ### Message types
#
# + System message - Tells the model how to behave and provide context for interactions
# + Human message - Represents user input and interactions with the model
# + AI message - Responses generated by the model, including text content, tool calls, and metadata
# + Tool message - Represents the outputs of tool calls

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage
messages = [
    SystemMessage("You are a data science expert"),
    HumanMessage("Explain about RAG Applications?")
]
response =  model.invoke(messages)
print(response.content)
# Out:
# **RAG (Retrieval-Augmented Generation)** is a powerful architectural pattern that combines the strengths of **Large Language Models (LLMs)** with **external knowledge retrieval systems**.
#
# It addresses key limitations of standalone LLMs, such as hallucinations, outdated knowledge, and lack of access to private or proprietary data.
#
# ---
#
# ### 🧠 Core Concept
#
# In a standard LLM:
# - The model generates text based **only** on its pre-trained weights.
# - It cannot access new information after training.
# - It may "hallucinate" (generate false but plausible information).
#
# In a **RAG system**:
# 1. **Retrieve**: The system searches an external knowledge base (e.g., documents, databases, APIs) for relevant information related to the user’s query.
# 2. **Augment**: The retrieved context is added to the user’s prompt.
# 3. **Generate**: The LLM uses both the user’s question **and** the retrieved context to generate a grounded, accurate response.
#
# > **Formula**:
# > `LLM Output = LLM( User Query + Retrieved Context )`
#
# ---
#
# ### 🏗️ How RAG Works (Step-by-Step)
#
# 1. **Ingestion & Indexing**:
#    - External documents (PDFs, web pages, databases) are processed.
#    - Text is split into **chunks**.
#    - Chunks are converted into **vector embeddings** using an embedding model.
#    - Vectors are stored in a **vector database** (e.g., Pinecone, Weaviate, Chroma, FAISS).
#
# 2. **Query Processing**:
#    - User asks a question.
#    - The query is also converted into a vector embedding.
#
# 3. **Retrieval**:
#    - The system searches the vector database for the **most similar** vectors to the query.
#    - Top-k relevant chunks are retrieved.
#
# 4. **Augmentation**:
#    - Retrieved chunks are formatted and inserted into the LLM’s prompt as context.
#
# 5. **Generation**:
#    - The LLM generates a response based on the user’s question **and** the provided context.
#    - The response is typically more accurate, up-to-date, and grounded in the source material.
#
# ---
#
# ### ✅ Key Benefits of RAG
#
# | Benefit | Explanation |
# |--------|-------------|
# | **Reduced Hallucinations** | The LLM is constrained to use provided context, making answers more factual. |
# | **Up-to-Date Knowledge** | You can update the knowledge base without retraining the LLM. |
# | **Access to Private Data** | Enables LLMs to use internal company documents, proprietary datasets, etc. |
# | **Cost-Effective** | No need for expensive fine-tuning; just update the vector store. |
# | **Explainability** | Responses can include citations or references to source documents. |
# | **Scalability** | Easy to add new documents or data sources. |
#
# ---
#
# ### ⚙️ Typical RAG Architecture Components
#
# 1. **Embedding Model**
#    Converts text into numerical vectors (e.g., `text-embedding-ada-002`, `BGE`, `OpenAI embeddings`).
#
# 2. **Vector Database**
#    Stores and retrieves similar vectors efficiently (e.g., Pinecone, Weaviate, Milvus, ChromaDB, FAISS).
#
# 3. **LLM**
#    Generates the final response (e.g., GPT-4, Llama 3, Mistral, Claude).
#
# 4. **Retriever**
#    Logic for finding relevant documents (similarity search, hybrid search, reranking).
#
# 5. **Prompt Template**
#    Structures how context and query are combined for the LLM.
#
# ---
#
# ### 📊 RAG vs. Fine-Tuning vs. Naive LLM
#
# | Feature | Naive LLM | Fine-Tuned LLM | RAG |
# |--------|-----------|----------------|-----|
# | **Knowledge Source** | Pre-training only | Pre-training + fine-tuning data | Pre-training + external knowledge base |
# | **Hallucination Risk** | High | Medium | Low (if retrieval is good) |
# | **Update Frequency** | Requires retraining | Requires retraining | Update vector DB only |
# | **Cost** | Low (inference only) | High (training + inference) | Medium (retrieval + inference) |
# | **Best For** | General knowledge | Specialized tone/format | Domain-specific, private, or dynamic data |
#
# ---
#
# ### 🚀 Common RAG Applications
#
# 1. **Enterprise Knowledge Bases**
#    - Employees ask natural language questions about internal policies, HR docs, or technical manuals.
#    - *Example*: "What is our vacation policy for full-time employees?"
#
# 2. **Customer Support Bots**
#    - Chatbots answer customer queries using product manuals, FAQs, and past tickets.
#    - *Example*: "How do I reset my password on the Pro plan?"
#
# 3. **Legal & Medical Assistants**
#    - Lawyers retrieve relevant case law; doctors access medical journals.
#    - *Example*: "Summarize recent rulings on data privacy in the EU."
#
# 4. **Financial Analysis**
#    - Analysts query financial reports, earnings calls, and market data.
#    - *Example*: "What were the key risk factors mentioned in Q3 earnings?"
#
# 5. **Research & Academic Tools**
#    - Researchers search across thousands of papers for relevant studies.
#    - *Example*: "Find studies on the impact of CRISPR on gene therapy."
#
# 6. **Code Assistance**
#    - Developers query internal codebases or documentation.
#    - *Example*: "How do I implement OAuth2 in our Python service?"
#
# ---
#
# ### 🔧 Advanced RAG Techniques
#
# 1. **Hybrid Search**: Combines **vector similarity** (semantic) with **keyword search** (BM25) for better retrieval.
# 2. **Reranking**: Uses a cross-encoder model to re-rank retrieved chunks for higher precision.
# 3. **Query Rewriting**: Improves the user’s query before retrieval (e.g., clarifying ambiguous questions).
# 4. **Multi-Step RAG (Self-RAG)**: The LLM iteratively retrieves, evaluates, and refines its own retrieval process.
# 5. **Graph RAG**: Uses knowledge graphs alongside vectors for complex relational queries.
# 6. **Caching**: Caches frequent queries to reduce latency and cost.
#
# ---
#
# ### ⚠️ Challenges & Limitations
#
# | Challenge | Mitigation |
# |----------|------------|
# | **Poor Retrieval Quality** | Use hybrid search, reranking, better embeddings, and chunking strategies. |
# | **Chunking Issues** | Optimize chunk size and overlap; use semantic chunking. |
# | **Context Window Limits** | Summarize retrieved docs; use top-k carefully. |
# | **Latency** | Use fast vector DBs, caching, and edge deployment. |
# | **Hallucinations Still Possible** | Enforce strict prompt engineering; add citations; use evaluation metrics. |
#
# ---
#
# ### 📈 Evaluation Metrics for RAG
#
# 1. **Faithfulness**: Is the answer grounded in the retrieved context?
# 2. **Relevance**: Does the answer address the user’s question?
# 3. **Retrieval Accuracy**: Did the retriever find the correct documents?
# 4. **Context Precision/Recall**: How much of the retrieved context is actually useful?
#
# Tools like **RAGAS**, **TruLens**, and **LangSmith** help evaluate RAG pipelines.
#
# ---
#
# ### 🛠️ Popular RAG Frameworks & Tools
#
# | Category | Tools |
# |---------|-------|
# | **Frameworks** | LangChain, LlamaIndex, Haystack, DSPy |
# | **Vector DBs** | Pinecone, Weaviate, Chroma, FAISS, Milvus, Qdrant |
# | **Embedding Models** | OpenAI, Cohere, Hugging Face (BGE, Sentence-Transformers) |
# | **LLMs** | GPT-4, Claude, Llama 3, Mistral, Gemini |
# | **Evaluation** | RAGAS, TruLens, LangSmith |
#
# ---
#
# ### 🧩 Simple RAG Code Example (Pseudocode)
#
# ```python
# # 1. Ingest documents
# documents = load_documents("company_handbook.pdf")
# chunks = split_documents(documents, chunk_size=500)
# embeddings = generate_embeddings(chunks)
# vector_db.upsert(embeddings)
#
# # 2. User query
# query = "What is the reimbursement limit for travel expenses?"
#
# # 3. Retrieve relevant chunks
# query_embedding = generate_embedding(query)
# relevant_chunks = vector_db.search(query_embedding, top_k=3)
#
# # 4. Augment prompt
# context = "\n".join(relevant_chunks)
# prompt = f"""
# Answer the question based ONLY on the following context:
# {context}
#
# Question: {query}
# Answer:
# """
#
# # 5. Generate response
# response = llm.generate(prompt)
# print(response)
# ```
#
# ---
#
# ### 📌 When to Use RAG vs. Other Approaches
#
# - **Use RAG when**:
#   - You need access to **private, proprietary, or frequently updated** data.
#   - You want to **reduce hallucinations** with cited sources.
#   - You want to **avoid costly fine-tuning**.
#
# - **Use Fine-Tuning when**:
#   -

# %%
system_msg = SystemMessage("You are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# # Creating a REST API
#
# A REST API (Representational State Transfer) is a standard way to build web services using HTTP methods. Here's a comprehensive guide:
#
# ## Core Principles
#
# | HTTP Method | Purpose |
# |-------------|---------|
# | `GET` | Retrieve resource(s) |
# | `POST` | Create a new resource |
# | `PUT` | Update an existing resource (full replacement) |
# | `PATCH` | Partially update a resource |
# | `DELETE` | Remove a resource |
#
# ## Example: Python with Flask
#
# ### 1. Install Dependencies
#
# ```bash
# pip install flask
# ```
#
# ### 2. Basic REST API
#
# ```python
# from flask import Flask, request, jsonify
# from datetime import datetime
#
# app = Flask(__name__)
#
# # In-memory "database"
# books = [
#     {"id": 1, "title": "The Great Gatsby", "author": "F. Scott Fitzgerald"},
#     {"id": 2, "title": "1984", "author": "George Orwell"},
# ]
# next_id = 3
#
# # --- GET: Retrieve all books ---
# @app.route('/books', methods=['GET'])
# def get_books():
#     return jsonify(books), 200
#
# # --- GET: Retrieve a single book ---
# @app.route('/books/<int:book_id>', methods=['GET'])
# def get_book(book_id):
#     book = next((b for b in books if b['id'] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#     return jsonify(book), 200
#
# # --- POST: Create a new book ---
# @app.route('/books', methods=['POST'])
# def create_book():
#     global next_id
#     data = request.get_json()
#
#     # Validate input
#     if not data or 'title' not in data or 'author' not in data:
#         return jsonify({"error": "title and author are required"}), 400
#
#     new_book = {
#         "id": next_id,
#         "title": data['title'],
#         "author": data['author']
#     }
#     books.append(new_book)
#     next_id += 1
#     return jsonify(new_book), 201
#
# # --- PUT: Update an existing book ---
# @app.route('/books/<int:book_id>', methods=['PUT'])
# def update_book(book_id):
#     global next_id
#     book = next((b for b in books if b['id'] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#
#     data = request.get_json()
#     if not data or 'title' not in data or 'author' not in data:
#         return jsonify({"error": "title and author are required"}), 400
#
#     book['title'] = data['title']
#     book['author'] = data['author']
#     return jsonify(book), 200
#
# # --- PATCH: Partially update a book ---
# @app.route('/books/<int:book_id>', methods=['PATCH'])
# def patch_book(book_id):
#     book = next((b for b in books if b['id'] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#
#     data = request.get_json()
#     if 'title' in data:
#         book['title'] = data['title']
#     if 'author' in data:
#         book['author'] = data['author']
#     return jsonify(book), 200
#
# # --- DELETE: Remove a book ---
# @app.route('/books/<int:book_id>', methods=['DELETE'])
# def delete_book(book_id):
#     global books
#     book = next((b for b in books if b['id'] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#
#     books = [b for b in books if b['id'] != book_id]
#     return jsonify({"message": "Book deleted"}), 200
#
# if __name__ == '__main__':
#     app.run(debug=True, port=5000)
# ```
#
# ### 3. Test with cURL
#
# ```bash
# # Get all books
# curl http://localhost:5000/books
#
# # Get a single book
# curl http://localhost:5000/books/1
#
# # Create a book
# curl -X POST http://localhost:5000/books \
#   -H "Content-Type: application/json" \
#   -d '{"title": "Dune", "author": "Frank Herbert"}'
#
# # Update a book
# curl -X PUT http://localhost:5000/books/1 \
#   -H "Content-Type: application/json" \
#   -d '{"title": "The Great Gatsby (Remastered)", "author": "F. Scott Fitzgerald"}'
#
# # Delete a book
# curl -X DELETE http://localhost:5000/books/1
# ```
#
# ## Best Practices
#
# 1. **Use proper status codes**
#    - `200` — Success
#    - `201` — Created
#    - `204` — No Content
#    - `400` — Bad Request
#    - `404` — Not Found
#    - `422` — Unprocessable Entity
#    - `500` — Server Error
#
# 2. **Use nouns in URLs**, not verbs
#    - ✅ `/books/1`
#    - ❌ `/getBook/1`
#
# 3. **Support filtering, sorting, and pagination**
#    ```
#    GET /books?author=Orwell&sort=title&limit=10&page=2
#    ```
#
# 4. **Validate all input** and return clear error messages
#
# 5. **Use versioning** for breakable changes
#    - `/api/v1/books`
#
# 6. **Handle errors consistently**
#    ```json
#    {
#      "error": "Book not found",
#      "code": 404
#    }
#    ```
#
# 7. **Use HTTPS** in production
#
# 8. **Add authentication** (API keys, JWT, OAuth) for protected endpoints
#
# ## Other Popular Frameworks
#
# | Language | Framework |
# |----------|-----------|
# | Python | Flask, FastAPI, Django REST Framework |
# | Node.js | Express, Fastify |
# | Java | Spring Boot |
# | Go | Gin, Echo |
# | Ruby | Sinatra, Rails |
#
# ## Next Steps
#
# - Add **database persistence** (SQLite, PostgreSQL, MongoDB)
# - Add **authentication** (e.g., JWT tokens)
# - Add **rate limiting**
# - Write **unit and integration tests**
# - Add **API documentation** (Swagger/OpenAPI)
# - Deploy to a cloud platform (AWS, GCP, Heroku, Render)
#
# Would you like a deeper dive into any specific part, such as authentication, database integration, or a different framework?

# %%
### Detailed Info to LLM wirh System Message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# # Creating a REST API in Python
#
# There are several popular frameworks for building REST APIs in Python. Below are examples using **FastAPI** (modern, fast, auto-docs) and **Flask** (simple, lightweight).
#
# ---
#
# ## Option 1: FastAPI (Recommended)
#
# FastAPI offers automatic validation, OpenAPI docs, and high performance.
#
# ### Install
# ```bash
# pip install fastapi uvicorn
# ```
#
# ### Basic API Example
#
# ```python
# # main.py
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from typing import Optional
#
# app = FastAPI()
#
# # --- Models (Pydantic schemas) ---
# class Item(BaseModel):
#     name: str
#     price: float
#     description: Optional[str] = None
#
# class ItemOut(BaseModel):
#     id: int
#     name: str
#     price: float
#     description: Optional[str] = None
#
# # --- In-memory "database" (replace with real DB in production) ---
# items_db: dict[int, ItemOut] = {}
# next_id = 1
#
# # --- Endpoints ---
#
# @app.get("/")
# def read_root():
#     return {"message": "Welcome to the REST API"}
#
# @app.get("/items", response_model=list[ItemOut])
# def get_items():
#     """List all items."""
#     return list(items_db.values())
#
# @app.get("/items/{item_id}", response_model=ItemOut)
# def get_item(item_id: int):
#     """Retrieve a single item by ID."""
#     item = items_db.get(item_id)
#     if item is None:
#         raise HTTPException(status_code=404, detail="Item not found")
#     return item
#
# @app.post("/items", response_model=ItemOut, status_code=201)
# def create_item(item: Item):
#     """Create a new item."""
#     global next_id
#     new_item = ItemOut(id=next_id, **item.dict())
#     items_db[next_id] = new_item
#     next_id += 1
#     return new_item
#
# @app.put("/items/{item_id}", response_model=ItemOut)
# def update_item(item_id: int, item: Item):
#     """Update an existing item."""
#     if item_id not in items_db:
#         raise HTTPException(status_code=404, detail="Item not found")
#     items_db[item_id] = ItemOut(id=item_id, **item.dict())
#     return items_db[item_id]
#
# @app.delete("/items/{item_id}", status_code=204)
# def delete_item(item_id: int):
#     """Delete an item."""
#     if item_id not in items_db:
#         raise HTTPException(status_code=404, detail="Item not found")
#     del items_db[item_id]
#     return None
# ```
#
# ### Run It
# ```bash
# uvicorn main:app --reload
# ```
#
# - API available at: `http://127.0.0.1:8000`
# - **Auto-generated docs** at: `http://127.0.0.1:8000/docs`
#
# ---
#
# ## Option 2: Flask (Lightweight)
#
# ### Install
# ```bash
# pip install flask
# ```
#
# ### Basic API Example
#
# ```python
# # main.py
# from flask import Flask, request, jsonify
#
# app = Flask(__name__)
#
# # --- In-memory "database" ---
# items_db = {}
# next_id = 1
#
# @app.route("/")
# def read_root():
#     return jsonify({"message": "Welcome to the REST API"})
#
# @app.route("/items", methods=["GET"])
# def get_items():
#     """List all items."""
#     return jsonify(list(items_db.values()))
#
# @app.route("/items/<int:item_id>", methods=["GET"])
# def get_item(item_id: int):
#     """Retrieve a single item by ID."""
#     item = items_db.get(item_id)
#     if item is None:
#         return jsonify({"error": "Item not found"}), 404
#     return jsonify(item)
#
# @app.route("/items", methods=["POST"])
# def create_item():
#     """Create a new item."""
#     global next_id
#     data = request.get_json()
#     if not data or "name" not in data or "price" not in data:
#         return jsonify({"error": "name and price are required"}), 400
#
#     new_item = {
#         "id": next_id,
#         "name": data["name"],
#         "price": float(data["price"]),
#         "description": data.get("description")
#     }
#     items_db[next_id] = new_item
#     next_id += 1
#     return jsonify(new_item), 201
#
# @app.route("/items/<int:item_id>", methods=["PUT"])
# def update_item(item_id: int):
#     """Update an existing item."""
#     if item_id not in items_db:
#         return jsonify({"error": "Item not found"}), 404
#
#     data = request.get_json()
#     items_db[item_id].update({
#         "name": data.get("name", items_db[item_id]["name"]),
#         "price": float(data.get("price", items_db[item_id]["price"])),
#         "description": data.get("description")
#     })
#     return jsonify(items_db[item_id])
#
# @app.route("/items/<int:item_id>", methods=["DELETE"])
# def delete_item(item_id: int):
#     """Delete an item."""
#     if item_id not in items_db:
#         return jsonify({"error": "Item not found"}), 404
#     del items_db[item_id]
#     return "", 204
#
# if __name__ == "__main__":
#     app.run(debug=True, port=5000)
# ```
#
# ### Run It
# ```bash
# python main.py
# ```
# - API available at: `http://127.0.0.1:5000`
#
# ---
#
# ## Key REST Principles
#
# | Principle | Description |
# |---|---|
# | **Resources** | Nouns in URLs (`/items`, `/users`) |
# | **HTTP Methods** | `GET` (read), `POST` (create), `PUT` (update), `DELETE` (remove) |
# | **Status Codes** | `200` OK, `201` Created, `404` Not Found, `400` Bad Request, `500` Server Error |
# | **Stateless** | Each request contains all info needed; no session state on server |
# | **JSON** | Standard data format for request/response bodies |
#
# ---
#
# ## Production Checklist
#
# 1. **Database** – Replace in-memory dicts with PostgreSQL/MySQL (use SQLAlchemy or Tortoise ORM)
# 2. **Authentication** – Add JWT or OAuth2 (FastAPI has built-in support)
# 3. **Validation** – Use Pydantic (FastAPI) or Marshmallow (Flask)
# 4. **Error Handling** – Consistent error response format
# 5. **Logging** – Add structured logging
# 6. **Testing** – Use `pytest` + `httpx` (FastAPI) or `flask.testing`
# 7. **Deployment** – Use Gunicorn/Uvicorn with a reverse proxy (Nginx)
#
# ### Example: Adding Auth with FastAPI
#
# ```python
# from fastapi import Depends, HTTPException
# from fastapi.security import OAuth2PasswordBearer
#
# oauth2_scheme = OAuth2PasswordBearer(tokenUrl="token")
#
# def get_current_user(token: str = Depends(oauth2_scheme)):
#     # Validate JWT here
#     if not token.startswith("valid-"):
#         raise HTTPException(status_code=401, detail="Invalid token")
#     return {"user_id": 1}
#
# @app.get("/items/{item_id}/owner")
# def get_item_owner(item_id: int, current_user: dict = Depends(get_current_user)):
#     # Only the owner can view this
#     ...
# ```
#
# ---
#
# ## Which Should You Choose?
#
# | Criteria | FastAPI | Flask |
# |---|---|---|
# | Speed | ⚡ Very fast (async) | Good |
# | Auto-docs | ✅ Built-in (Swagger) | ❌ Needs plugin |
# | Type hints / Validation | ✅ Native (Pydantic) | ⚠️ External libs |
# | Learning curve | Slightly steeper | Easier |
# | Best for | New projects, high performance | Simple services, microservices |
#
# **For new projects, FastAPI is generally the better choice** due to built-in validation, documentation, and performance.

# %%
### Message Metadata
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
response = model.invoke([
  human_msg
])
response

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 112,
#  'output_tokens': 30,
#  'total_tokens': 142,
#  'output_token_details': {'reasoning': 11}}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content='The weather in San\u202fFrancisco is **Sunny, 72\u202f°F**.', additional_kwargs={'reasoning_content': 'We have a function call get_weather returned "Sunny, 72°F". That is the answer. But we need to respond to user. The user asked "What\'s the weather in San Francisco?" The assistant responded with the function call, then the function returned "Sunny, 72°F". According to policy, we should give the final answer. So we respond: "The weather in San Francisco is Sunny, 72°F."'}, response_metadata={'token_usage': {'completion_tokens': 113, 'prompt_tokens': 109, 'total_tokens': 222, 'completion_time': 0.123731884, 'completion_tokens_details': {'reasoning_tokens': 87}, 'prompt_time': 0.052263827, 'prompt_tokens_details': None, 'queue_time': 0.410129362, 'total_time': 0.175995711}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_5979a0e1b7', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0aeea-8786-79a1-b395-e478a6d05650-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 113, 'total_tokens': 222, 'output_token_details': {'reasoning': 87}})
