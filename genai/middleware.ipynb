# %% [markdown]
# ## Middleware
# Middleware provides a way to more tightly control what happens inside the agent. Middleware is useful for the following:
#
# + Tracking agent behavior with logging, analytics, and debugging.
# + Transforming prompts, tool selection, and output formatting.
# + Adding retries, fallbacks, and early termination logic.
# + Applying rate limits, guardrails, and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Summarization MiddleWare
# Automatically summarize conversation history when approaching token limits, preserving recent messages while compressing older context. Summarization is useful for the following:
#
# Long-running conversations that exceed context windows.
# Multi-turn dialogues with extensive history.
# Applications where preserving full conversation context matters.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage, SystemMessage

# Agent with message based summarisation

agent = create_agent(
    model="gpt-5",
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-5",
            trigger=("messages",10),
            keep=("messages",4)
        )
    ]
)
agent

# %%
## thread id
config={"configurable":{"thread_id":"test1"}}

# %%
#Alternative test data
questions = [
    "What is 2+2?",
    "What is 10*5?",
    "What is 100/4?",
    "What is 15-7?",
    "What is 3*3?",
    "What is 4*4?",
]
for q in questions:
    response=agent.invoke({"messages":[HumanMessage(content=q)]}, config)
    print(f"Messages:{response}")
    print(f"Messages: {len(response['messages'])}")
# Out:
# Messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3623bfa4-ead8-49ca-8c94-8dd86f0373f7'), AIMessage(content='4', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 13, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoq8HQELqAX5LkrOXcK5O3xP9pD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-3547-70e2-8fc6-586f7bfeef48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 74, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})]}
# Messages: 2
# Messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3623bfa4-ead8-49ca-8c94-8dd86f0373f7'), AIMessage(content='4', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 13, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoq8HQELqAX5LkrOXcK5O3xP9pD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-3547-70e2-8fc6-586f7bfeef48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 74, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='d5510185-75b6-41f8-9cdb-1535c2c55e64'), AIMessage(content='50', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 31, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOosofqpL1VyRk71H1L6LNrcLIHb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-45b4-7ea3-9e26-8ff98f181eaa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 10, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Messages: 4
# Messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3623bfa4-ead8-49ca-8c94-8dd86f0373f7'), AIMessage(content='4', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 13, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoq8HQELqAX5LkrOXcK5O3xP9pD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-3547-70e2-8fc6-586f7bfeef48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 74, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='d5510185-75b6-41f8-9cdb-1535c2c55e64'), AIMessage(content='50', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 31, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOosofqpL1VyRk71H1L6LNrcLIHb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-45b4-7ea3-9e26-8ff98f181eaa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 10, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='f9ca0e36-76d0-44ec-ac07-cd5ae6f5a260'), AIMessage(content='25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 49, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOovvBQF4gsjpPQkRUq5KeDECzqk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-4d6d-74b0-8c6c-dfd6969af697-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 10, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Messages: 6
# Messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3623bfa4-ead8-49ca-8c94-8dd86f0373f7'), AIMessage(content='4', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 13, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoq8HQELqAX5LkrOXcK5O3xP9pD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-3547-70e2-8fc6-586f7bfeef48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 74, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='d5510185-75b6-41f8-9cdb-1535c2c55e64'), AIMessage(content='50', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 31, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOosofqpL1VyRk71H1L6LNrcLIHb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-45b4-7ea3-9e26-8ff98f181eaa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 10, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='f9ca0e36-76d0-44ec-ac07-cd5ae6f5a260'), AIMessage(content='25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 49, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOovvBQF4gsjpPQkRUq5KeDECzqk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-4d6d-74b0-8c6c-dfd6969af697-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 10, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='5da3bdd9-60fb-4bda-9a4a-96ba66ffaa28'), AIMessage(content='8', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 67, 'total_tokens': 77, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoxqYOWCGaYGGAxFxYp5B6uOknS', 'service_tier': 'default', 'finish ...
# Messages: 8
# Messages:{'messages': [HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='3623bfa4-ead8-49ca-8c94-8dd86f0373f7'), AIMessage(content='4', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 13, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoq8HQELqAX5LkrOXcK5O3xP9pD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-3547-70e2-8fc6-586f7bfeef48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 74, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='d5510185-75b6-41f8-9cdb-1535c2c55e64'), AIMessage(content='50', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 31, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOosofqpL1VyRk71H1L6LNrcLIHb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-45b4-7ea3-9e26-8ff98f181eaa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 10, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='f9ca0e36-76d0-44ec-ac07-cd5ae6f5a260'), AIMessage(content='25', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 49, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOovvBQF4gsjpPQkRUq5KeDECzqk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-4d6d-74b0-8c6c-dfd6969af697-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 10, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='5da3bdd9-60fb-4bda-9a4a-96ba66ffaa28'), AIMessage(content='8', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 67, 'total_tokens': 77, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoxqYOWCGaYGGAxFxYp5B6uOknS', 'service_tier': 'default', 'finish ...
# Messages: 10
# Messages:{'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nAnswer a sequence of basic arithmetic questions with concise numeric results; the next pending question is "What is 15-7?".\n\n## SUMMARY\n- The user is asking straightforward arithmetic problems and expects immediate numeric answers.\n- Q&A so far:\n  - 2+2 = 4\n  - 10*5 = 50\n  - 100/4 = 25\n- No alternative approaches or tools were needed; responses are direct calculations. No rejected options.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\n- Compute and provide the answer to "What is 15-7?" → 8\n- Continue answering any subsequent arithmetic questions succinctly.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='f9fa9b79-302f-485e-8cc5-6043f1260596'), AIMessage(content='8', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 67, 'total_tokens': 77, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoxqYOWCGaYGGAxFxYp5B6uOknS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-5673-7202-a262-d65a5ef58649-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 10, 'total_tokens': 77, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='84d2b1e0-07b2-459f-b468-b9da47691101'), AIMessage(content='9', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 85, 'total_tokens': 95, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOoyJWiv2K9kF8SR4NK2qjGI5Uma', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-5dad-70b3-b7d4-efc5bd4b8930-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 85, 'output_tokens': 10, 'total_tokens': 95, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 4*4?', additional_kwargs={}, response_metadata={}, id='dc313aad-36be-4df0-b9ae-59c1ef0f1aa0'), AIMessage(content='16', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 196, 'total_tokens': 206, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOp7rsFKXeOG7FlGDkf7kuD0haH1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3c3-8196-72e0-86af-f76c301074a6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 196, 'output_tokens': 10, 'total_tokens': 206, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Messages: 6

# %% [markdown]
# ### Token size

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

@tool
def search_hotels(city: str) -> str:
    """Search hotels - returns long response to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""

agent = create_agent(
    model = "gpt-5",
    tools = [search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model = "gpt-5",
            trigger =("tokens",500),
            keep = ("tokens",200),
        )
    ]
)

config = {"configurable": {"thread_id":"test-1"}}

# Token counter (approximate)
def count_tokens(messages):
    total_chars = sum(len(str(m.content)) for m in messages)
    return total_chars // 4  # 4 chars ≈ 1 token

# %%
# Run test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
        config=config
    )
    
    tokens = count_tokens(response["messages"])
    print(f"{city}: ~{tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")
# Out:
# Paris: ~150 tokens, 4 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='d553f885-e2f3-4f64-b8e3-3ec2ff7237ac'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 152, 'prompt_tokens': 134, 'total_tokens': 286, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOw9my9DlohA9z3B6Y4PxKnsupo9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3ca-25fe-7122-9308-1265a5e01122-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_EoIsCt0HmTQjGTKEdS2Fe6bp', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 134, 'output_tokens': 152, 'total_tokens': 286, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='b37db86c-cfb1-445e-8a05-539382ceed7e', tool_call_id='call_EoIsCt0HmTQjGTKEdS2Fe6bp'), AIMessage(content='Here are some options in Paris:\n- Grand Hotel — 5-star, about $350/night, spa, pool, gym\n- City Inn — 4-star, about $180/night, business center\n- Budget Stay — 3-star, about $75/night, free Wi‑Fi\n\nWant me to narrow it down? Share your travel dates, budget per night, preferred neighborhood (e.g., near the Eiffel Tower, Louvre, Le Marais), star rating, number of guests/rooms, and any must-have amenities.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 373, 'prompt_tokens': 224, 'total_tokens': 597, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOwCEr6vFGEFhWBRqa77D1XVZscD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3ca-3221-7421-bcbc-678950f197a1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 224, 'output_tokens': 373, 'total_tokens': 597, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]
# London: ~800 tokens, 5 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nFind and recommend hotels in Paris tailored to the user\'s trip details and preferences.\n\n## SUMMARY\n- The user asked to find hotels in Paris but provided no trip details (dates, guests/rooms, budget, neighborhoods, star rating, amenities, cancellation policy, loyalty preferences).\n- The assistant performed an initial broad search for Paris and presented three example options:\n  - Grand Hotel — 5-star, ~$350/night, spa, pool, gym\n  - City Inn — 4-star, ~$180/night, business center\n  - Budget Stay — 3-star, ~$75/night, free Wi‑Fi\n- Current strategy: pause further searching and collect key requirements to refine results. Avoid committing to a shortlist or booking until preferences and constraints are known.\n- No options were rejected; preliminary results are placeholders pending user inputs.\n\n## ARTIFACTS\n- Tool call: search_hotels({ city: "Paris" }).\n- Output captured: three candidate hotels with star ratings, approximate nightly rates, and basic amenities (listed above).\n\n## NEXT STEPS\n- Collect from the user:\n  - Check-in/check-out dates and flexibility\n  - Number of guests, rooms, and bed configuration\n  - Nightly budget and currency\n  - Preferred neighborhoods/landmarks (arrondissements)\n  - Desired hotel type/star rating\n  - Must-have amenities (e.g., A/C, Wi‑Fi, breakfast, gym, pool, parking, pet-friendly, accessibility)\n  - Cancellation/refund flexibility\n  - Loyalty programs or preferred booking platforms\n  - Special constraints (e.g., noise sensitivity, elevator requirement)\n- After gathering details: perform a refined, filtered search; compile a tailored shortlist (3–6 options) with current prices, key pros/cons, neighborhood context, and booking links/options.\n- Do not repeat the unfiltered search without new user inputs.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='2d15fdf6-3541-42ab-8850-bdf39db8f4ef'), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='015a754d-df48-40f9-9301-326011cb0051'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 280, 'prompt_tokens': 574, 'total_tokens': 854, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EPOwTh4DJC5rUlq5ufAn7nTkz7DmU', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3ca-74a8-7b60-8abf-4a8a10b82d3c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_eiGxbDyVOlxh03ZIVoSxws0K', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 574, 'output_tokens': 280, 'total_tokens': 854, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='9fd030b0-5e45-4e75-91e9-cfdc218a41e7', tool_call_id='call_eiGxbDyVOlxh03ZIVoSxws0K'), AIMessage(content='I can help you find the right London hotel, tailored to your trip. From a quick broad scan, here are just sample ranges (not a final shortlist):\n- Grand Hotel — 5-star, ~$350/night, spa/pool/gym\n- City Inn — 4-star, ~$180/night, business-focused\n- Budget Stay — 3-star, ~$75/night, free Wi‑Fi\n\nTo refine accurate options with current prices and availability, please share:\n- Dates: check-in/check-out (flexible?)\n- Travelers: adults/children, rooms, b ...
# Tokyo: ~933 tokens, 3 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nFind and recommend hotels in London tailored to the user’s trip details and preferences, then deliver a refined shortlist once requirements are known.\n\n## SUMMARY\n- The user shifted destination focus from Paris to London.\n- Assistant performed an initial broad search for London and shared three placeholder examples (not a final shortlist) to illustrate range and set expectations.\n- Agreed strategy: pause further searching until key trip requirements are provided; then produce a tailored shortlist with current availability/pricing. Avoid committing to bookings or repeating unfiltered searches without inputs.\n- No options accepted or rejected; awaiting user details.\n\n## ARTIFACTS\n- Tool call: search_hotels({ city: "London" }).\n- Output (placeholders):\n  - Grand Hotel — 5-star, ~$350/night, spa/pool/gym\n  - City Inn — 4-star, ~$180/night, business center\n  - Budget Stay — 3-star, ~$75/night, free Wi‑Fi\n\n## NEXT STEPS\n- Collect from user:\n  - Dates (check-in/check-out; flexibility)\n  - Travelers (adults/children), rooms, bed setup\n  - Budget (nightly target and currency)\n  - Location preferences (e.g., Covent Garden/Soho, South Bank, Kensington, City/Bank, Shoreditch, King’s Cross, Canary Wharf)\n  - Hotel style/star level (luxury/boutique/mid-range/budget; chain vs independent)\n  - Must-have amenities (A/C, Wi‑Fi, breakfast, gym, pool, parking, pet-friendly, accessible room, elevator, quiet room, workspace, near Tube)\n  - Cancellation/refund flexibility\n  - Loyalty programs or preferred booking platforms\n  - Any special considerations (e.g., stroller/wheelchair, noise sensitivity, elevator requirement, late check-in)\n- After receiving details: run a refined, filtered search and deliver 3–6 well-matched options with current prices, pros/cons, neighborhood context, and booking links/options.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='63d422f7-1e25-48a1-b714-33a5b964f207'), HumanMessage(content='Find hotels in Tokyo', additional_kwargs={}, response_metadata={}, id='f18a205c-a623-4eaf-a033-f0ed5f9ac8bf'), AIMessage(content='Great—happy to help with Tokyo. To tailor a shortlist with current availability and prices, could you share:\n\n- Dates: check-in/check-out and any flexibility\n- Travelers: adults/children, number of rooms, preferred bed setup (note: Japan “semi-double” beds are small; many couples prefer twin rooms)\n- Budget: target nightly range and currency\n- Preferred areas or sights to be near (e.g., Shinjuku, Shibuya, Ginza/Tokyo Station, Asakusa/Ueno, Roppongi, Odaiba, Shinagawa, Ikebukuro, Disney/Maihama)\n- Hotel style/star level: luxury, boutique, mid-range, budget; chain vs independent; any interest in ryokan or capsule options\n- Must-haves: non-smoking room, A/C, breakfast, gym/pool, on-site onsen/public bath, washer/dryer, kitchenette, elevator, accessible room, parking, quiet room, workspace, near JR/Yamanote or a specific subway line\n- Flexibility: free cancellation needed?\n- Loyalty: programs or preferred booking platforms\n- Special considerations: stroller/wheelchair, late check-in, luggage storage, airport access (HND/NRT), language support\n\nNeighborhood quick picks (to help you choose):\n- Shinjuku: major hub, nightlife, great transit, lots of dining; busy\n- Shibuya: youthful, shopping/dining, good connections\n- Ginza/Marunouchi/Tokyo Station: upscale, walkable to Imperial Palace, easiest for shinkansen/airport links\n- Asakusa/Ueno: traditional sights, museums, value stays, more low-rise\n- Roppongi/Azabu: nightlife, art museums, many international-friendly hotels\n- Shinagawa: super convenient for shinkansen and Haneda; quieter at night\n- Ikebukuro: good value, big stations, lots of food\n- Odaiba: bay views, family-friendly attractions; farther from center\n- Disney/Maihama: best for park days\n\nOnce I have your details, I’ll deliver 3–6 spot-on o ...
# New York: ~976 tokens, 3 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nFind and recommend hotels in Tokyo tailored to the user’s trip details and preferences, then deliver a refined shortlist with current availability and prices once requirements are provided.\n\n## SUMMARY\n- Destination focus has shifted from London to Tokyo.\n- Agreed workflow: pause searching until key trip requirements are provided; then produce a tailored shortlist (3–6 options) with live prices, pros/cons, neighborhood context, and booking options; avoid unfiltered searches or commitments without inputs.\n- Assistant requested trip details for Tokyo, including:\n  - Dates (check-in/check-out; flexibility)\n  - Travelers, rooms, and bed setup (note: Japan “semi-double” beds are small; many couples prefer twin rooms)\n  - Budget and currency\n  - Preferred areas/sights (e.g., Shinjuku, Shibuya, Ginza/Tokyo Station, Asakusa/Ueno, Roppongi/Azabu, Shinagawa, Ikebukuro, Odaiba, Disney/Maihama)\n  - Hotel style/star level (luxury/boutique/mid-range/budget; chain vs independent; interest in ryokan/capsule)\n  - Must-haves (non-smoking, A/C, breakfast, gym/pool, on-site onsen/public bath, washer/dryer, kitchenette, elevator, accessible room, parking, quiet room, workspace, near JR/Yamanote or specific subway line)\n  - Cancellation/refund flexibility\n  - Loyalty programs or preferred booking platforms\n  - Special considerations (stroller/wheelchair, late check-in, luggage storage, airport access HND/NRT, language support)\n- No Tokyo search has been run yet; awaiting user inputs.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\n- Collect the above trip details from the user.\n- Once received, run a refined, filtered Tokyo hotel search and return 3–6 well-matched options with live prices/availability, pros/cons, neighborhood context, transit/airport access notes, cancellation terms, and booking links.\n- If inputs are incomplete, ask targeted follow-ups and confirm airport (HND vs NRT) and neighborhood priorities.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='e69ddad3-def1-4583-a25a-d85482bfdf79'), HumanMessage(content='Find hotels in New York', additional_kwargs={}, response_metadata={}, id='3fb6d8c8-6ec6-40a0-a53f-9763cce1fb39'), AIMessage(content='Happy to help with New York. To build a tailored shortlist with live prices and availability, could you share:\n\n- Dates: check-in/check-out and any flexibility\n- Travelers: adults, kids (ages), number of rooms, bed setup (1 king vs 2 beds; need connecting rooms or a crib)\n- Budget: target nightly budget in USD (before tax/fees); flexibility; ok with destination/resort fees (often $20–$50/nt)?\n- Neighborhoods or vibe: Manhattan only or open to Brooklyn/Queens? Any must-see sights you want to be near?\n- Hotel style: luxury, upscale, boutique, mid-range, extended-stay/aparthotel; chain vs independent; suite/kitchenette interest\n- Must-haves: non-smoking, breakfast included, gym/pool, club lounge, pet-friendly, accessible room, quiet room, view, workspace, kitchenette, washer/dryer, parking, late check-in, luggage storage\n- Transit: prefer walking to key sights, near a specific subway line/station, or near Penn Station/Grand Central?\n- Cancellation: fully refundable vs nonrefundable OK\n- Loyalty: Marriott/Hilton/Hyatt/IHG/Accor/SLH, or preferred booking platform\n- Airport: arriving/departing JFK, LGA, or EWR; need easy transit access?\n\nIf it helps, quick neighborhood guide (pick any that fit):\n- Midtown/Times Square: central for first-time sightseeing/Broadway\n- Central Park South/Upper West/East: museums, greener, more residential\n- Chelsea/Flatiron/NoMad: dining, galleries, High Line\n- SoHo/Tribeca: boutiques, restaurants, loft vibe\n- Lower East Side/East Village: nightlife, indie eateries\n- Financial District/Battery Park: quiet at night, near Statue of Liberty/One World\n- Brooklyn (Williamsburg/DUMBO/Brooklyn Heights): trendy, views, calmer\n- Long Isl ...
# Dubai: ~1238 tokens, 3 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nFind and recommend hotels in New York City tailored to the user’s trip details and preferences, then deliver a refined shortlist with current availability and prices once requirements are provided.\n\n## SUMMARY\n- Destination pivoted to New York at the user’s request (supersedes prior Tokyo focus).\n- Agreed workflow: pause searching until key trip requirements are provided; then produce a tailored shortlist (3–6 options) with live prices/availability, pros/cons, neighborhood context, transit/airport access notes, cancellation terms, and booking links; avoid broad/unfiltered searches or commitments without inputs to ensure relevance and up-to-date pricing.\n- Assistant requested the following NYC trip details:\n  - Dates: check-in/check-out and flexibility\n  - Travelers: adults, kids (ages), number of rooms, bed setup (1 king vs 2 beds; connecting rooms or crib)\n  - Budget: target nightly budget in USD (before tax/fees); flexibility; comfort with destination/resort fees\n  - Neighborhoods or vibe: Manhattan only or open to Brooklyn/Queens; proximity to desired sights\n  - Hotel style: luxury/upscale/boutique/mid-range/extended-stay; chain vs independent; suite/kitchenette interest\n  - Must-haves: non-smoking, breakfast, gym/pool, club lounge, pet-friendly, accessible room, quiet room, view, workspace, kitchenette, washer/dryer, parking, late check-in, luggage storage\n  - Transit priorities: walking distance vs near specific subway line/station; proximity to Penn Station or Grand Central\n  - Cancellation: fully refundable vs nonrefundable acceptable\n  - Loyalty: Marriott/Hilton/Hyatt/IHG/Accor/SLH or preferred booking platform\n  - Airport: arriving/departing JFK, LGA, or EWR; need easy transit access\n- Neighborhood guide provided for selection: Midtown/Times Square; Central Park South/Upper West/East; Chelsea/Flatiron/NoMad; SoHo/Tribeca; Lower East Side/East Village; Financial District/Battery Park; Brooklyn (Williamsburg/DUMBO/Brooklyn Heights); Long Island City (Queens).\n- No NYC hotel search has been run yet; awaiting user inputs.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\n- Await the user’s NYC trip details listed above.\n- Upon receipt, run a refined, filtered NYC hotel search and return 3–6 well-matched options with live prices/availability, pros/cons, neighborhood context, transit/airport access notes, cancellation terms, and booking links.\n- If inputs are incomplete, ask targeted follow-ups and confirm airport choice and neighborhood priorities/budget flexibility.', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='a52274e9-48dc-4e40-a503-f8478f95264f'), HumanMessage(content='Find hotels in Dubai', additional_kwargs={}, response_metadata={}, id='c2b29973-5ea9-40c6-8730-50b7540e1309'), AIMessage(content='Happy to help with Dubai. To build a spot‑on shortlist with live prices and availability, please share:\n\n- Dates: check-in/check-out and any flexibility\n- Travelers: adults, kids (ages), number of rooms, bed setup (1 king vs 2 beds; connecting rooms or crib)\n- Budget: target nightly rate (USD or AED) before tax/fees; flexibility; okay with daily Tourism Dirham fee (~AED 10–20/night)\n- Area/vibe: beach resort vs city/landmarks vs old Dubai culture\n- Hotel style: luxury/upscale/boutique/mid-range/serviced apartments; chain vs independent\n- Must-haves: breakfast, pool, beach access, kids’ club, club lounge, gym/spa, kitchen/kitchenette, washer/dryer, balcony/view, non-smoking, accessible room, late check-in, parking\n- Transit: walkable to Metro vs fine with taxis; prefer near Dubai Mall/Burj Khalifa, Marina/JBR, Palm, Expo City, etc.\n- Cancellation: fully refundable vs can consider nonrefundable\n- Loyalty: Marriott/Hilton/Hyatt/Accor/IHG/SLH or preferred booking platform\n- Airport: arriving/departing DXB (most common) or DWC/AUH; need airport transfer?\n\nQuick area guide to help you choo ...
# Singapore: ~1147 tokens, 3 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nFind and recommend hotels in Dubai tailored to the user’s trip details and preferences, then deliver a refined shortlist with current availability and prices once requirements are provided.\n\n## SUMMARY\n- Destination pivoted from New York City to Dubai at the user’s request (Dubai focus supersedes prior NYC plan).\n- Agreed workflow: wait for key trip requirements; then produce a tailored shortlist (3–6 options) with live prices/availability, pros/cons, area/neighborhood context, transit/airport access notes, cancellation terms, and booking links; avoid broad/unfiltered searches or stale pricing.\n- Assistant requested Dubai trip details:\n  - Dates: check-in/check-out and flexibility\n  - Travelers: adults, kids (ages), number of rooms, bed setup (1 king vs 2 beds; connecting rooms or crib)\n  - Budget: target nightly rate (USD or AED) before tax/fees; flexibility; okay with Tourism Dirham fee (~AED 10–20/night)\n  - Area/vibe: beach resort vs city/landmarks vs heritage/old Dubai\n  - Hotel style: luxury/upscale/boutique/mid-range/serviced apartments; chain vs independent\n  - Must-haves: breakfast, pool, beach access, kids’ club, club lounge, gym/spa, kitchen/kitchenette, washer/dryer, balcony/view, non-smoking, accessible room, late check-in, parking\n  - Transit: walkable to Metro vs fine with taxis; prefer near Dubai Mall/Burj Khalifa, Marina/JBR, Palm, Expo City, etc.\n  - Cancellation: fully refundable vs can consider nonrefundable\n  - Loyalty: Marriott/Hilton/Hyatt/Accor/IHG/SLH or preferred booking platform\n  - Airport: arriving/departing DXB (most common) or DWC/AUH; need airport transfer?\n- Dubai area guide provided to help choose:\n  - Downtown Dubai (Burj Khalifa/Dubai Mall): best for first-timers; Metro access.\n  - Business Bay: near Downtown; modern, good value.\n  - DIFC: upscale/business; excellent restaurants; central.\n  - Dubai Marina & JBR: lively beachfront; family-friendly; possible traffic.\n  - Palm Jumeirah: luxury beachfront; quieter; longer rides to sights.\n  - Jumeirah/Madinat/Um Suqeim: beach by Burj Al Arab; resort feel.\n  - Al Barsha (Mall of the Emirates): value and suites; Metro.\n  - Dubai Creek/Deira/Al Seef: heritage vibe; souks; great value; close to DXB.\n  - Bluewaters Island: premium beachfront next to JBR; newer resorts.\n  - Trade Centre/Sheikh Zayed Road: central spine; quick Metro/taxi to most areas.\n  - Expo City/Dubai South: best for nearby events; far from city/beach.\n- No Dubai hotel search has been run yet; awaiting user inputs.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\n- Await the user’s Dubai trip details listed above.\n- Upon receipt, run a refined, filtered Dubai hotel search and return 3–6 well-matched options with live prices/availability, pros/cons, area context, transit/airport access notes, cancellation terms, and booking links.\n- If inputs are incomplete, ask targeted follow-ups and confirm airport choice, area priorities, and budget flexibility; can also start from a single top-priority brief (e.g., “luxury beachfront for a couple” or “2-bedroom serviced apartment near Downtown under $250/night”).', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='c1f3e3b8-2b81-47e7-b23b-20faa8ead5e4'), HumanMessage(content='Find hotels in Singapore', additional_kwargs={}, response_metadata={}, id='2aad44d0-bd5d-46ea-a1fb-05504cb6d595'), AIMessage(content='Happy to help. Quick check: should we switch focus from Dubai to Singapore now, or is this a separate trip?\n\nShare a few trip details and I’ll pull a tailored shortlist (3–6 hotels) with live prices/availability, pros/cons, area context, transit notes, and booking links:\n- Dates: check-in/check-out and flexibility\n- Travelers: adults, kids (ages), rooms needed, bed setup (1 king vs 2 beds), connecting rooms or crib?\n- Budget: target nightly rate (SGD or USD) before tax/fees; any flexibility\n- Area/vi ...

# %% [markdown]
# ### Fraction

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

@tool
def search_hotels(city: str) -> str:
    """Search hotels."""
    return f"Hotels in {city}: Grand Hotel $350, City Inn $180, Budget Stay $75"

# LOW fraction for testing!
agent = create_agent(
    model="gpt-4o-mini",
    tools=[search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("fraction", 0.005),  # 0.5% = ~640 tokens
            keep=("fraction", 0.002),     # 0.2% = ~256 tokens
        ),
    ],
)

config = {"configurable": {"thread_id": "test-1"}}

# Token counter
def count_tokens(messages):
    return sum(len(str(m.content)) for m in messages) // 4

# Test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Hotels in {city}")]},
        config=config
    )
    tokens = count_tokens(response["messages"])
    fraction = tokens / 128000  # gpt-4o-mini context
    print(f"{city}: ~{tokens} tokens ({fraction:.4%}), {len(response['messages'])} msgs")
    print(response['messages'])
# Out:
# Paris: ~68 tokens (0.0531%), 4 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='5fbbbb97-10a8-4763-8967-9571a2a9c6e1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3fnfrIyJkoiZL7ueLF2ArdJi2g', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4187-7c20-8cc1-aae151ecfb81-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BnLTZn6eGpcpQxIuWBrSgTuW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='bf2bc869-83c7-49ff-95ab-901ae90b3c0a', tool_call_id='call_BnLTZn6eGpcpQxIuWBrSgTuW'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nWould you like more information about any of these hotels?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 86, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3gSbynowJewEYTlcg8jCov7EWX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3d1-46ba-73b3-b70b-f713e3a20490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 55, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# London: ~139 tokens (0.1086%), 8 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='5fbbbb97-10a8-4763-8967-9571a2a9c6e1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3fnfrIyJkoiZL7ueLF2ArdJi2g', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4187-7c20-8cc1-aae151ecfb81-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BnLTZn6eGpcpQxIuWBrSgTuW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='bf2bc869-83c7-49ff-95ab-901ae90b3c0a', tool_call_id='call_BnLTZn6eGpcpQxIuWBrSgTuW'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nWould you like more information about any of these hotels?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 86, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3gSbynowJewEYTlcg8jCov7EWX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3d1-46ba-73b3-b70b-f713e3a20490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 55, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='65e63b07-27b1-4eba-893b-864ced20490b'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 151, 'total_tokens': 166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3h7kAmGzgBPARN41XU3x6CmSPe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4b38-7b93-b016-9200c1ceb24c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_buOEGjnFtGz9ZsqVz1rnJwrA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 15, 'total_tokens': 166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='ae50dbb2-6a06-4e32-9de5-a25ed1831929', tool_call_id='call_buOEGjnFtGz9ZsqVz1rnJwrA'), AIMessage ...
# Tokyo: ~209 tokens (0.1633%), 12 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='5fbbbb97-10a8-4763-8967-9571a2a9c6e1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3fnfrIyJkoiZL7ueLF2ArdJi2g', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4187-7c20-8cc1-aae151ecfb81-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BnLTZn6eGpcpQxIuWBrSgTuW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='bf2bc869-83c7-49ff-95ab-901ae90b3c0a', tool_call_id='call_BnLTZn6eGpcpQxIuWBrSgTuW'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nWould you like more information about any of these hotels?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 86, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3gSbynowJewEYTlcg8jCov7EWX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3d1-46ba-73b3-b70b-f713e3a20490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 55, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='65e63b07-27b1-4eba-893b-864ced20490b'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 151, 'total_tokens': 166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3h7kAmGzgBPARN41XU3x6CmSPe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4b38-7b93-b016-9200c1ceb24c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_buOEGjnFtGz9ZsqVz1rnJwrA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 15, 'total_tokens': 166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='ae50dbb2-6a06-4e32-9de5-a25ed1831929', tool_call_id='call_buOEGjnFtGz9ZsqVz1rnJwrA'), AIMessage ...
# New York: ~284 tokens (0.2219%), 16 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='5fbbbb97-10a8-4763-8967-9571a2a9c6e1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3fnfrIyJkoiZL7ueLF2ArdJi2g', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4187-7c20-8cc1-aae151ecfb81-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BnLTZn6eGpcpQxIuWBrSgTuW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='bf2bc869-83c7-49ff-95ab-901ae90b3c0a', tool_call_id='call_BnLTZn6eGpcpQxIuWBrSgTuW'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nWould you like more information about any of these hotels?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 86, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3gSbynowJewEYTlcg8jCov7EWX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3d1-46ba-73b3-b70b-f713e3a20490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 55, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='65e63b07-27b1-4eba-893b-864ced20490b'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 151, 'total_tokens': 166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3h7kAmGzgBPARN41XU3x6CmSPe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4b38-7b93-b016-9200c1ceb24c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_buOEGjnFtGz9ZsqVz1rnJwrA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 15, 'total_tokens': 166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='ae50dbb2-6a06-4e32-9de5-a25ed1831929', tool_call_id='call_buOEGjnFtGz9ZsqVz1rnJwrA'), AIMessage ...
# Dubai: ~352 tokens (0.2750%), 20 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='5fbbbb97-10a8-4763-8967-9571a2a9c6e1'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3fnfrIyJkoiZL7ueLF2ArdJi2g', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4187-7c20-8cc1-aae151ecfb81-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BnLTZn6eGpcpQxIuWBrSgTuW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='bf2bc869-83c7-49ff-95ab-901ae90b3c0a', tool_call_id='call_BnLTZn6eGpcpQxIuWBrSgTuW'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nWould you like more information about any of these hotels?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 86, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3gSbynowJewEYTlcg8jCov7EWX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3d1-46ba-73b3-b70b-f713e3a20490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 55, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='65e63b07-27b1-4eba-893b-864ced20490b'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 151, 'total_tokens': 166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3h7kAmGzgBPARN41XU3x6CmSPe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-4b38-7b93-b016-9200c1ceb24c-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_buOEGjnFtGz9ZsqVz1rnJwrA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 15, 'total_tokens': 166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='ae50dbb2-6a06-4e32-9de5-a25ed1831929', tool_call_id='call_buOEGjnFtGz9ZsqVz1rnJwrA'), AIMessage ...
# Singapore: ~434 tokens (0.3391%), 12 msgs
# [HumanMessage(content="Here is a summary of the conversation to date:\n\n## SESSION INTENT\n\nThe user's primary goal is to find hotels in various cities, including Paris, London, Tokyo, and New York.\n\n## SUMMARY\n\nThe user requested hotels in multiple cities, and the assistant provided hotel options for each:\n- **Paris**: \n  1. Grand Hotel - $350\n  2. City Inn - $180\n  3. Budget Stay - $75\n- **London**: \n  1. Grand Hotel - $350\n  2. City Inn - $180\n  3. Budget Stay - $75\n- **Tokyo**: \n  1. Grand Hotel - $350\n  2. City Inn - $180\n  3. Budget Stay - $75\nThe assistant offered to provide more information about any of the hotels listed but has not yet received a further request from the user for New York.\n\n## ARTIFACTS\n\nNone\n\n## NEXT STEPS\n\nThe assistant should wait for the user's request regarding hotels in New York to complete the information search for that city.", additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='775d8dd5-7145-4065-953c-95513fa6802e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 371, 'total_tokens': 387, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3lBhi9hP9oQ2mQxjaQxJnhO2IU', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d1-5cf3-7603-a1b2-0c16df56f0d9-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New York'}, 'id': 'call_3X7EVXE1SQVzlnP7AupogUci', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 371, 'output_tokens': 16, 'total_tokens': 387, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in New York: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='abba7812-0b4d-4e0b-9ee3-469dd75bbdfd', tool_call_id='call_3X7EVXE1SQVzlnP7AupogUci'), AIMessage(content='Here are some hotels in New York:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you would like more information about any of these hotels!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 415, 'total_tokens': 475, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c06c62446c', 'id': 'chatcmpl-EPP3mxOwtVRklqHKryVr9lnVQLzGQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3d1-6004-7461-ad7d-4f23f8328ce6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 415, 'output_tokens': 60, 'total_tokens': 475, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in Dubai', additional_kwargs={}, response_metadata={}, id='52cad55c-6fa7-4c65-8559-a1a9c840feab'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 485, 'total_tokens': 500, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write ...

# %% [markdown]
# ## Human In the Loop MiddleWare
# Pause agent execution for human approval, editing, or rejection of tool calls before they execute. Human-in-the-loop is useful for the following:
#
# High-stakes operations requiring human approval (e.g. database writes, financial transactions).
# Compliance workflows where human oversight is mandatory.
# Long-running conversations where human feedback guides the agent.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver

def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

# %%
agent=create_agent(
    model="gpt-4o",
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool":{
                    "allowed_decisions":["approve","edit","reject"]
                },
                "read_email_tool":False,

            }
        )
    ]
)
agent

# %%
config = {"configurable": {"thread_id": "test-approve"}}
# Step 1: Request
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='e52174d5-cc3a-4fef-94fd-2ec1180ccec2'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f6d02d065', 'id': 'chatcmpl-EPPABm9bNxJphz1OgWzuNevjcosLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3d7-674d-7713-b574-8830d26847f5-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_wBOHzjzfXJCAYhYcR9Ht8bb0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='2fb9b1d51a6e49a1bb1decec8cc551bb')]}

# %%
from langgraph.types import Command
# Step 2: Approve
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result: The email has been sent to john@test.com with the subject "Hello."

# %%
config = {"configurable": {"thread_id": "test-reject"}}
# Step 1: Request
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config)

# %%
# Step 2: Reject
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "reject"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result: It looks like there was an issue with sending the email. If you'd like to try again or make any changes, please let me know!

# %% [markdown]
# ## Editing

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model="gpt-4o",
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-edit"}}

# Step 1: Request (with wrong info)
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='419fe241-7660-4aef-b817-fe002d53c11a'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 95, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f6d02d065', 'id': 'chatcmpl-EPPHiqAn7XzlzxZsGZziEA2sFGphC', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3de-871d-7743-af81-1a73767fb897-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}, 'id': 'call_EXaiIV1GrDvBNnRipHvvLfoI', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 95, 'output_tokens': 25, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='ac0eb452af2a6926859176140f530c85')]}

# %%
# Step 2: Edit and approve
if "__interrupt__" in result:
    print("⏸️ Paused! Editing...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {
                        "type": "edit",
                        "edited_action": {
                            "name": "send_email_tool",      # Tool name
                            "args": {                   # New arguments
                                "recipient": "correct@email.com",
                                "subject": "Corrected Subject",
                                "body": "This was edited by human before sending"
                            }
                        }
                    }
                ]
            }
        ),
        config=config
    )
    
    print(f"✏️ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Editing...
# ✏️ Result: The email has been sent to correct@email.com with the subject 'Corrected Subject.'

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='419fe241-7660-4aef-b817-fe002d53c11a'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 95, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f6d02d065', 'id': 'chatcmpl-EPPHiqAn7XzlzxZsGZziEA2sFGphC', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0b3de-871d-7743-af81-1a73767fb897-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email_tool', 'args': {'recipient': 'correct@email.com', 'subject': 'Corrected Subject', 'body': 'This was edited by human before sending'}, 'id': 'call_EXaiIV1GrDvBNnRipHvvLfoI'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 95, 'output_tokens': 25, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Email sent to correct@email.com with subject 'Corrected Subject'", name='send_email_tool', id='767f4e44-87f3-44db-b17e-1948e607b4db', tool_call_id='call_EXaiIV1GrDvBNnRipHvvLfoI'),
#   AIMessage(content="The email has been sent to correct@email.com with the subject 'Corrected Subject.'", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 150, 'total_tokens': 168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f6d02d065', 'id': 'chatcmpl-EPPHvomZmfi4J9NB1CNGNVUBv594q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0b3de-c0f1-71b2-b338-5813d283dad6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 150, 'output_tokens': 18, 'total_tokens': 168, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
